# %%
#Load data from excel file
# 1. Load data from excel file
# 2. Clean data
# 3. Save data to csv file
import pandas as pd
import os

path = os.path.join("data", "Fredagsbarer_oversigt.xlsx")
df = pd.read_excel(path)

# %%
df
# Out:
#                                name  \
# 0                         Theos Bar
# 1                          KOMMAbar
# 2                              FRED
# 3                     Fredagsbar.dk
# 4                     Symposion Bar
# 5                         Panta Rei
# 6                         Esperanto
# 7                      KaserneBaren
# 8                          Barbaren
# 9                             Arken
# 10                          BarBund
# 11                          Paideia
# 12                           ARABAR
# 13                           Eforen
# 14                   Studenterbaren
# 15                  Studentercaféen
# 16                          Klubben
# 17  Økonomisk Forening/Konverterbar
# 18       Samfundsfaglig Fredagsbar*
# 19               The CORNER of Birk
# 20                        Umbilicus
# 21                           Siffos
# 22                       Apollonia
# 23                Beerceps Maximus
# 24                     Kalkulerbar
# 25               Fysisk Fredagsbar
# 26                    Fredagscaféen
# 27        Alkymia Kemisk Fredagsbar
# 28                  Katrines Kælder
# 29                          Nanobar
# 30                     TÅGEKAMMERET
# 31                    Die Rote Zone
# 32      Biogas/Biologisk Fredagsbar
# 33                   Broca's Bodega
# 34                         Haddokks
# 35                          Globarl
# 36                            Chaos
# 37                   ApproksimerBar
#
#                                             address          geo location  \
# 0                Jens Chr. Skous Vej 3, 8000 Aarhus  56.172225, 10.205504
# 1                Jens Chr. Skous Vej 2, 8000 Aarhus  56.172649, 10.206183
# 2                Jens Chr. Skous Vej 2, 8000 Aarhus  56.172894, 10.206625
# 3                    Helsingforsgade 8, 8200 Aarhus  56.171192, 10.192434
# 4                   Jens Chr. Skousvej 3 1451 - 116  56.172048, 10.205637
# 5                Jens Chr. Skous Vej 7, 8000 Aarhus  56.172862, 10.204763
# 6                    Nordre Ringgade 1, 8000 Aarhus  56.172795, 10.205207
# 7                                Langelandsgade 139  56.167461, 10.197725
# 8              Moesgaard Allé 20, Højbjerg, Denmark  56.086986, 10.226371
# 9               Moesgård Allé 20, Højbjerg, Denmark  56.086986, 10.226371
# 10                                              NaN                   NaN
# 11           Jens Chr. Skous vej 4, Aarhus, Denmark  56.172715, 10.206213
# 12                            Jens Chr. Skous Vej 7  56.172725, 10.204706
# 13        Karl Verners Vej 2, Aarhus, Denmark, 8000   56.168940,10.199240
# 14                                Nordre Ringgade 3  56.171361, 10.200270
# 15                                              NaN                   NaN
# 16               Fuglesangs Alle 4, Aarhus, Denmark  56.162169, 10.182515
# 17              Fuglesangs Allé 26, Aarhus, Denmark  56.164112, 10.182154
# 18               Bartholins Allé 8, Aarhus, Denmark  56.169863, 10.204565
# 19             Birk Centerpark 15, Herning, Denmark   56.129270, 9.030998
# 20           Ole Worms Allé 2, 8000 Aarhus, Danmark  56.167674, 10.201779
# 21  Ole Worms Allé 2, Bygning 1150, Aarhus, Denmark  56.167674, 10.201779
# 22   Høegh-Guldbergs Gade 8, 8000 Aarhus C, Danmark  56.164243, 10.205797
# 23                 Dalgas Avenue 4, Aarhus, Denmark  56.143459, 10.199314
# 24                  Ny Munkegade 118, 8000 Aarhus C  56.166569, 10.198322
# 25                                 Ny Munkegade 120  56.167368, 10.198912
# 26                Helsingforsgade 14, 8200 Aarhus N  56.171692, 10.188634
# 27              Langelandsgade 140, Aarhus, Denmark  56.168321, 10.198891
# 28                 Finlandsgade 22, Aarhus, Denmark  56.171895, 10.191195
# 29             Gustav Wieds vej 14, Aarhus, Denmark  56.168945, 10.198099
# 30                Ny Munkegade 118, Aarhus, Denmark                   NaN
# 31                      Universitetsbyen 81, aarhus  56.170355, 10.207679
# 32           Wilhelm Meyers Allé 5, Aarhus, Denmark  56.166986, 10.203244
# 33                            Jens Chr. Skous vej 4  56.172709, 10.206343
# 34           Inge Lehmanns Gade 10, Aarhus, Denmark  56.158913, 10.214742
# 35           Jens Chr. Skous Vej 7, Aarhus, Denmark  56.172883, 10.204688
# 36              Høegh-Guldbergs Gade 2, 8000 Aarhus  56.163164, 10.209482
# 37                     Gustav Wieds Vej 10A, Aarhus  56.167646, 10.193084
#
#                                           information  \
# 0                      Teologi og Religionsvidenskabs
# 1                               Nordisk og Lingvistik
# 2                                Historisk fredagsbar
# 3                               Informationsvidenskab
# 4   Fredagsbar for Klassisk Arkæologi og Klassisk ...
# 5                             Filosofi og idéhistorie
# 6          Engelsk, Spansk, Tysk og Fransk IVK og SLK
# 7                          Institut for Æstetiske Fag
# 8                                         Antropologi
# 9                              arkæologisk fredagsbar
# 10                                                NaN
# 11                            Pædagogik og Uddannelse
# 12                           Arabisk- og Islamstudier
# 13                                                NaN
# 14            Fælles studenterbar for alle studerende
# 15                                                NaN
# 16             School of Business and Social Sciences
# 17                     Økonomisk Forenings fredagsbar
# 18  Psykologi, Jura, Statskundskab, Samfundsfag og...
# 19                                                NaN
# 20                                Medicins fredagsbar
# 21                             Folkesundhedsvidenskab
# 22                                    Tandlægestudiet
# 23                                  Idræts fredagsbar
# 24          matematisk institut på Aarhus Universitet
# 25                                  fysisk fredagsbar
# 26                                           Datalogi
# 27                                  Kemisk fredagsbar
# 28                            Ingenørernes fredagsbar
# 29                                        nanoscience
# 30  dækker fagene matematik, matematik-økonomi, da...
# 31                                   Molekylærbiologi
# 32                                            Biologi
# 33                                  Cognitive Science
# 34                ngeniør- og maskinmester-studerende
# 35                        Globale Studiers Fredagsbar
# 36                               Geologisk Fredagsbar
# 37                                 Civilingeniørernes
#
#                building - room  opening hours  \
# 0                         1451    16.00-24.00
# 1                   1485 - 137    16.00-23.00
# 2                   1484 - 134    16.00-00.00
# 3              5008 - kælderen    14.00-02.00
# 4                   1451 - 116    16.00-22.00
# 5                   1457 - 515    16.00-22.00
# 6                   1482 - 147    16.00-23.45
# 7   580 - Kasernescenens foyer    14.00-00.00
# 8                         4206    15.00-23.00
# 9                         4206    15.00-22.00
# 10                         NaN            NaN
# 11                        1485  16.00 - 01.00
# 12                  1465 - 115    18.00-00.00
# 13                         NaN            NaN
# 14                        1422    12.00-03.00
# 15                         NaN            NaN
# 16                    2623 (B)    12.00-02.00
# 17                   2640 (R)     15.00-20.00
# 18                        1320    15.00-19.00
# 19                         NaN    11.00-18-00
# 20                        1150    15.00-02.00
# 21                        1150    17.00-23.00
# 22                        1614    16.00-02.00
# 23                         NaN            NaN
# 24                        1521    15.00-22.00
# 25                  1525 - 231    16.00-22.00
# 26                         NaN    15.00-22.00
# 27                        1510    15.30-02.00
# 28                        5125    14.00-02.00
# 29                        1590    16.00-22.00
# 30                         NaN            NaN
# 31                     1873 K3    15.00-23.00
# 32                        1222    15.00-22.00
# 33                        1485    16.00-02.00
# 34                     Navitas    14.00-02.00
# 35                  1465 - 115    16.00-00.00
# 36                        1672    15.00-02.00
# 37                         NaN    16.00-22.00
#
#                                          social media  prices  floor_quality  \
# 0                https://www.facebook.com/TheosBarAU/     low             10
# 1   https://www.facebook.com/Kommabarerfredagsbar/...    high              7
# 2   https://www.facebook.com/historiskfredagsbarfr...     low              9
# 3   https://www.facebook.com/fredagsbar.dk/?locale...  medium             10
# 4    https://www.facebook.com/symposion.klassisk.bar/  medium              8
# 5   https://www.facebook.com/people/Panta-Rei-fred...  medium              5
# 6      https://www.facebook.com/AUEsperantoFridayBar/  medium              3
# 7         https://www.facebook.com/Kasernebaren/about  medium              5
# 8   https://www.facebook.com/p/Barbaren-Antropolog...  medium              7
# 9   https://www.facebook.com/Arkenfredagsbar/?loca...  medium              1
# 10                                                NaN  medium              5
# 11  https://www.facebook.com/PAIDEIABARN/?locale=d...  medium              4
# 12                 https://www.facebook.com/ArabarAU/    high              4
# 13                                                NaN    high              8
# 14  https://www.facebook.com/Studenterbaren/?local...    high              2
# 15                                                NaN    high              2
# 16  https://www.facebook.com/Klubben.dk/?locale=da_DK    high             10
# 17  https://www.facebook.com/konverterbar/?locale=...  medium              7
# 18  https://www.facebook.com/samfundsfagligfredags...  medium              5
# 19    https://www.facebook.com/CornerOfBirkFridayBar/  medium              8
# 20                https://www.facebook.com/JeresUMBI/  medium              9
# 21      https://www.facebook.com/siffos/?locale=da_DK  medium              4
# 22  https://www.facebook.com/people/Apollonia-Tand...  medium              3
# 23                                                NaN  medium              6
# 24  https://www.facebook.com/Kalkulerbar/?locale=d...  medium              7
# 25  https://www.facebook.com/FysiskFredagsBar/?loc...     low              8
# 26  https://www.facebook.com/fredagscafeen.dk/?loc...     low              8
# 27                 https://www.facebook.com/lkymiaAU/     low              2
# 28  https://www.facebook.com/KatrinesKaelder/?loca...     low              8
# 29                https://www.facebook.com/Nanobaren/     low              7
# 30  https://www.facebook.com/TAAGEKAMMERET/?locale...     low              3
# 31                                                NaN  medium              9
# 32  https://www.facebook.com/367934280699775/photo...  medium              3
# 33  https://www.facebook.com/brocasbodega/?locale=...  medium             10
# 34                 https://www.facebook.com/Haddokks/  medium              3
# 35                  https://www.facebook.com/Globarl/  medium              7
# 36  https://www.facebook.com/groups/chaosbar/?loca...  medium              8
# 37           https://www.facebook.com/approksimerbar/  medium              6
#
#     love_potential  hygge_factor wheelchair_access  party_factor
# 0                9             9               yes          10.0
# 1                7             7               yes           9.0
# 2                6             6                no           9.0
# 3                7             8               yes          10.0
# 4                5             5                no           7.0
# 5                7             8                no           8.0
# 6                4             7               yes           7.0
# 7                7             9               yes           5.0
# 8                8             8               yes           7.0
# 9                6             8               yes           5.0
# 10               7             5               yes           4.0
# 11               6             6                no           8.0
# 12               6             8               yes           5.0
# 13               9             7               yes           4.0
# 14               7             6                no           8.0
# 15               6             9               yes           NaN
# 16               7             7                no          10.0
# 17               5             6                no           7.0
# 18               7             8               yes           6.0
# 19               4             5               yes           3.0
# 20               7             8               yes          10.0
# 21               8             7               yes           7.0
# 22               6             9               yes           4.0
# 23               7             8                no           8.0
# 24               6             8               yes           3.0
# 25               6             5               yes           4.0
# 26               9             6                no           4.0
# 27               7             8               yes           5.0
# 28               6             7                no           9.0
# 29               7             6                no           6.0
# 30               5             9               yes           8.0
# 31               7             8               yes           3.0
# 32               4             8               yes           3.0
# 33               7             5               yes          10.0
# 34               8             6               yes           3.0
# 35               6             8                no           4.0
# 36               7             7               yes           2.0
# 37               6             6               yes           5.0

# %%
import folium

# Create a Map centered around Aarhus
m = folium.Map(location=[56.1629, 10.2039], zoom_start=13)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c386c449f884c4d36db562d57a8bbcb9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c386c449f884c4d36db562d57a8bbcb9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c386c449f884c4d36db562d57a8bbcb9 = L.map(
#                 &quot;map_c386c449f884c4d36db562d57a8bbcb9&quot;,
#                 {
#                     center: [56.1629, 10.2039],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6955cc1aee323504858ddc6f8ccf0285 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c386c449f884c4d36db562d57a8bbcb9);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [Name, Address, Geo location, Information, Building - room, Opening hours, Social media, Prices]
# Index: []

# %%
for index, row in df.iterrows():
    # check if the geo-location exists and is not NaN
    if pd.notna(row['Geo location']):
        try:
            # split the Geo location into latitude and longitude
            lat, lon = map(float, row['Geo location'].split(','))
            
            # format the popup string
            popup_text = f"""
                            <h4>{row['Name']}</h4><br>
                            <b>Address: </b>{row['Address']}<br>
                            <b>Opening hours: </b>{row['Opening hours']}<br>
                            <b>SoMe: </b><a href="{row['Social media']}">Link</a><br>
                            <b>Information: </b>{row['Information']}<br>
                            <b>Prices: </b>{row['Prices']}<br>
                        """
            # Create the folium marker and add to the map
            folium.Marker(
                location=[lat, lon],
                popup=folium.Popup(popup_text, max_width=250)
            ).add_to(m)
        except Exception as e:
            print(f"Error with row {index}: {e}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Geo location'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[69], line 3
#       1 for index, row in df.iterrows():
#       2     # check if the geo-location exists and is not NaN
# ----> 3     if pd.notna(row['Geo location']):
#       4         try:
#       5             # split the Geo location into latitude and longitude
#       6             lat, lon = map(float, row['Geo location'].split(','))
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/series.py:981, in Series.__getitem__(self, key)
#     978     return self._values[key]
#     980 elif key_is_scalar:
# --> 981     return self._get_value(key)
#     983 if is_hashable(key):
#     984     # Otherwise index.get_value will raise InvalidIndexError
#     985     try:
#     986         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/series.py:1089, in Series._get_value(self, label, takeable)
#    1086     return self._values[label]
#    1088 # Similar to Index.get_value, but we do not fall back to positional
# -> 1089 loc = self.index.get_loc(label)
#    1090 return self.index._get_values_for_loc(self, loc, label)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'Geo location'

# %%
from flask import Flask, render_template, request
import pandas as pd
import folium

app = Flask(__name__)

# load the csv file
path = os.path.join("data", "Fredagsbarer_oversigt.xlsx")
df = pd.read_excel(path)

@app.route('/')
def home():
    return render_template('home.html')

if __name__ == '__main__':
    app.run(debug=True) # one launching into production, set debug=False
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
#  * Restarting with stat
# /Users/wibe/Library/Python/3.9/lib/python/site-packages/traitlets/traitlets.py:2548: FutureWarning: Supporting extra quotes around strings is deprecated in traitlets 5.0. You can use 'hmac-sha256' instead of '"hmac-sha256"' if you require traitlets >=5.
#   warn(
# /Users/wibe/Library/Python/3.9/lib/python/site-packages/traitlets/traitlets.py:2499: FutureWarning: Supporting extra quotes around Bytes is deprecated in traitlets 5.0. Use '19aa8730-1efa-4c3d-877a-c3d09630aace' instead of 'b"19aa8730-1efa-4c3d-877a-c3d09630aace"'.
#   warn(
# Traceback (most recent call last):
#   File "/Users/wibe/Library/Python/3.9/lib/python/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/Users/wibe/Library/Python/3.9/lib/python/site-packages/traitlets/config/application.py", line 1042, in launch_instance
#     app.initialize(argv)
#   File "/Users/wibe/Library/Python/3.9/lib/python/site-packages/traitlets/config/application.py", line 113, in inner
#     return method(app, *args, **kwargs)
#   File "/Users/wibe/Library/Python/3.9/lib/python/site-packages/ipykernel/kernelapp.py", line 678, in initialize
#     self.init_sockets()
#   File "/Users/wibe/Library/Python/3.9/lib/python/site-packages/ipykernel/kernelapp.py", line 317, in init_sockets
#     self.shell_port = self._bind_socket(self.shell_socket, self.shell_port)
#   File "/Users/wibe/Library/Python/3.9/lib/python/site-packages/ipykernel/kernelapp.py", line 252, in _bind_socket
#     return self._try_bind_socket(s, port)
#   File "/Users/wibe/Library/Python/3.9/lib/python/site-packages/ipykernel/kernelapp.py", line 228, in _try_bind_socket
#     s.bind("tcp://%s:%i" % (self.ip, port))
#   File "/Users/wibe/Library/Python/3.9/lib/python/site-packages/zmq/sugar/socket.py", line 301, in bind
#     super().bind(addr)
#   File "zmq/backend/cython/socket.pyx", line 564, in zmq.backend.cython.socket.Socket.bind
#   File "zmq/backend/cython/checkrc.pxd", line 28, in zmq.backend.cython.checkrc._check_rc
# zmq.error.ZMQError: Address already in use
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# /Users/wibe/Library/Python/3.9/lib/python/site-packages/IPython/core/interactiveshell.py:3513: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
